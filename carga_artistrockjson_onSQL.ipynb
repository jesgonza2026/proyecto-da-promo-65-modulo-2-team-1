# %% [markdown]
# Importamos y abrimos el json que cada una tiene guardado

# %%
import mysql.connector
from mysql.connector import errorcode
import pandas as pd
import json

# %% [markdown]
# Esto lo he copiado del archivo experimento_api

# %%
with open('files/artistas_rock_completo.json', 'r', encoding='utf-8') as f:
    lista_artistas_rock = json.load(f)

# %% [markdown]
# Abrimos el json correcto que tengo guardado con todos los datos para cargar a sql

# %%
df_rock = pd.DataFrame(lista_artistas_rock)

# %%
df_rock
# Out:
#                           id         artist_name            track_name genre  \
# 0     3Cfa9yZMsAPX0KJVr47g9W        Unorthodocks         Snapple Facts  rock
# 1     3Cfa9yZMsAPX0KJVr47g9W            Funk.Shu         Snapple Facts  rock
# 2     0i7wsxCMVxxSQbH8HZZ8HQ                Taxi                 Grita  rock
# 3     7JCmaxxkWIcq8BRiSKHH9V          Anne-Marie    2002 - KREAM Remix  rock
# 4     7JCmaxxkWIcq8BRiSKHH9V               KREAM    2002 - KREAM Remix  rock
# ...                      ...                 ...                   ...   ...
# 1865  09KDB5l9Teu4Jmi0rcX6hT            Rawayana           CAMINAAANDO  rock
# 1866  3ITvhrRB5TlEks19k9qy2k      Fontaines D.C.  Jackie Down The Line  rock
# 1867  0DHUNPj3jZU9MfBuVIgSKi  El Cuarteto De Nos      El Cinturón Gris  rock
# 1868  7LHAKF7pBqHch8o6Yo0ad5            RADWIMPS  Suzume (feat. Toaka)  rock
# 1869  2w7Ca8DNYXBCgA6Bht7o0N           Rammstein             Zick Zack  rock
#
#       year
# 0     2018
# 1     2018
# ...

# %% [markdown]
# Ahora hacemos la conexion con el servidor

# %%
usuario = "root"
password = "xxxxxxxxx"
host = "127.0.0.1"
base_de_datos = "pandemusic" # Asegúrate de haber creado el Schema en Workbench

# %%
# !pip install sqlalchemy mysql-connector-python
#esto si queremos no tener que hacer la lista de tuplas
# Out:
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    -------------- ------------------------- 0.8/2.1 MB 9.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 6.9 MB/s  0:00:00
# ...
#
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    ---------------------------------------- 2/2 [sqlalchemy]
#
# ...

# %%
#lo importamos 
from sqlalchemy import create_engine

# %%
#creamos el engine a ver que tal
engine = create_engine(f"mysql+mysqlconnector://{usuario}:{password}@{host}/{base_de_datos}")
try:
    df_rock.to_sql('tabla_rock', con=engine, if_exists="replace", index=False)
    print("✅ ¡Conexión exitosa! Los artistas se han guardado en la tabla 'tabla_rock'.")
except Exception as e:
    print(f"❌ Ups, algo falló: {e}")
# Out:
# ✅ ¡Conexión exitosa! Los artistas se han guardado en la tabla 'tabla_rock'.
