# %%
import mysql.connector
from mysql.connector import errorcode
import pandas as pd
import json
from sqlalchemy import create_engine
#importar lo que necesitamos

# %%
with open('files/json_general.json', 'r', encoding='utf-8') as f:
    lista_artistas_general = json.load(f)

# %%
lista_artistas_general
# Out:
# [{'id': '4MtYi2kZ0Ep8Abx8HK0IOY',
#   'artist_name': 'Dubskie',
#   'track_name': 'Can You Not (feat. Lox Chatterbox)',
#   'genre': 'rap',
#   'year': 2018},
#  {'id': '4MtYi2kZ0Ep8Abx8HK0IOY',
#   'artist_name': 'Lox Chatterbox',
#   'track_name': 'Can You Not (feat. Lox Chatterbox)',
#   'genre': 'rap',
#   'year': 2018},
#  {'id': '2Gwu3amAkMPfVOd540PfmZ',
#   'artist_name': 'Carlito',
#   'track_name': 'Zahia',
#   'genre': 'rap',
#   'year': 2018},
#  {'id': '17PJDAPRSZ862hBqeJWme8',
#   'artist_name': 'DJ Funky',
#   'track_name': "Tanzen geh'n",
#   'genre': 'rap',
#   'year': 2018},
#  {'id': '3BKnrSjpvJu9gaCTQK7Vw7',
#   'artist_name': 'Pakman Jitt',
#   'track_name': 'Packs',
#   'genre': 'rap',
#   'year': 2018},
#  {'id': '5OoGls5XlcHsftjnETfY6w',
#   'artist_name': 'Ladyy Acee',
#   'track_name': 'Relate',
#   'genre': 'rap',
#   'year': 2018},
#  {'id': '40PFhkJKrQFXi3TwYjwzGp',
#   'artist_name': 'Roland Prince',
#   'track_name': 'Fivepointfive.',
# ...

# %%
df_lista_artistas_general = pd.DataFrame(lista_artistas_general)

# %%
df_lista_artistas_general
# Out:
#                            id           artist_name  \
# 0      4MtYi2kZ0Ep8Abx8HK0IOY               Dubskie
# 1      4MtYi2kZ0Ep8Abx8HK0IOY        Lox Chatterbox
# 2      2Gwu3amAkMPfVOd540PfmZ               Carlito
# 3      17PJDAPRSZ862hBqeJWme8              DJ Funky
# 4      3BKnrSjpvJu9gaCTQK7Vw7           Pakman Jitt
# ...                       ...                   ...
# 11724  0GQqUziZTC1ry5ZG5Clkl1                  ajan
# 11725  4KLJuUPIIRPuAiIbxhLjgI                 Joost
# 11726  17atS5LacDzLe3a5vbeQTx        Playa Cuberris
# 11727  5nI1jkXMIwrzR0EUbDu07D      Celebration Guns
# 11728  0j2cPfSxLUospUfyO4lxtQ  La Decada Prodigiosa
#
#                                track_name genre  year
# 0      Can You Not (feat. Lox Chatterbox)   rap  2018
# 1      Can You Not (feat. Lox Chatterbox)   rap  2018
# 2                                   Zahia   rap  2018
# 3                            Tanzen geh'n   rap  2018
# 4                                   Packs   rap  2018
# ...

# %%
usuario = "root"
password = "AlumnaAdalab"
host = "127.0.0.1"
base_de_datos = "pandemusic" # Asegúrate de haber creado el Schema en Workbench

# %%
#creamos el engine a ver que tal
engine = create_engine(f"mysql+mysqlconnector://{usuario}:{password}@{host}/{base_de_datos}")
try:
    df_lista_artistas_general.to_sql('tabla_artistas_canciones', con=engine, if_exists="replace", index=False)
    print("✅ ¡Conexión exitosa! Los artistas se han guardado en la tabla 'tabla_general'.")
except Exception as e:
    print(f"❌ Ups, algo falló: {e}")
# Out:
# ✅ ¡Conexión exitosa! Los artistas se han guardado en la tabla 'tabla_rock'.

# %%
#pones tus credenciales de mysql workbench
usuario = "root"
password = "xxxxxx"
host = "127.0.0.1"
base_de_datos = "pandemusic" # Asegúrate de haber creado el Schema en Workbench

# %%
from sqlalchemy import create_engine

# %%
#creamos el engine a ver que tal
engine = create_engine(f"mysql+mysqlconnector://{usuario}:{password}@{host}/{base_de_datos}")
try:
    df_hiphop.to_sql('tabla_hiphop', con=engine, if_exists="replace", index=False)
    print("✅ ¡Conexión exitosa! Los artistas se han guardado en la tabla 'tabla_hiphop'.")
except Exception as e:
    print(f"❌ Ups, algo falló: {e}")
