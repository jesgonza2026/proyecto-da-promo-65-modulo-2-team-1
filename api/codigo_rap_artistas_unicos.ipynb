# %%
import json
import pandas as pd
import requests

# %%
#primero voy a abrir el archivo json, definitivo.json
with open('Files/definitivo.json', 'r') as archivo_json:
    fuente_json = json.load(archivo_json)

# %%
type(fuente_json)
# Out:
# list

# %%
fuente_json
# Out:
# [{'id': '7AlYBA5M9FVXDqN31cbExE',
#   'artist_name': 'Remedios Amaya',
#   'track_name': 'El zarandeo',
#   'genre': 'flamenco',
#   'year': 2000},
#  {'id': '4uqcES2h19TKAXQlciycrO',
#   'artist_name': 'Nobuo Uematsu',
#   'track_name': "Vamo'alla flamenco",
#   'genre': 'flamenco',
#   'year': 2000},
#  {'id': '0z6xGK2u3nSsbk9XeKYwZQ',
#   'artist_name': 'Maurice Ravel',
#   'track_name': 'Flamenco Bolero',
#   'genre': 'flamenco',
#   'year': 2000},
#  {'id': '6DjfWx0fXi0uQpedpvaCD9',
#   'artist_name': 'Mark Towns',
#   'track_name': 'After the Rain',
#   'genre': 'flamenco',
#   'year': 2000},
#  {'id': '1t91qQaPbOoo4pumaLih4W',
#   'artist_name': 'Franz Schubert',
#   'track_name': 'Tango Serenata (Ständchen)',
#   'genre': 'flamenco',
#   'year': 2000},
#  {'id': '7Kuasu0H7jArcADoFIHGUk',
#   'artist_name': 'Mark Towns',
#   'track_name': 'Corriente',
#   'genre': 'flamenco',
#   'year': 2000},
#  {'id': '02jM23k8pgm9gcZpyIn8Wk',
#   'artist_name': 'Georges Moustaki',
# ...

# %%
len(fuente_json)
# Out:
# 61617

# %%
df_fuente_json = pd.read_json('Files/definitivo.json') 
df_fuente_json.head(1000)
# Out:
#                          id     artist_name                    track_name  \
# 0    7AlYBA5M9FVXDqN31cbExE  Remedios Amaya                   El zarandeo
# 1    4uqcES2h19TKAXQlciycrO   Nobuo Uematsu            Vamo'alla flamenco
# 2    0z6xGK2u3nSsbk9XeKYwZQ   Maurice Ravel               Flamenco Bolero
# 3    6DjfWx0fXi0uQpedpvaCD9      Mark Towns                After the Rain
# 4    1t91qQaPbOoo4pumaLih4W  Franz Schubert    Tango Serenata (Ständchen)
# ..                      ...             ...                           ...
# 995  0l1VmlgGHZXYL0CR27ryRz       Jo Basile         Je T'Aime Encore Plus
# 996  4rs0A9RRJy6BPR1Mq1czcZ   Guddu Rangila         Ab Naahi Sutem Kinara
# 997  57eMvbS96z94E6KzRaEOEj     Lindisfarne                      Shine On
# 998  6A8Nhein0Z7Ug2Gfh08ox1   Marcos Sabino                Paz e Harmonia
# 999  3WoVUGUsSc5hvpLQnyJqRa       Ted Heath  I Like To Recognise The Tune
#
#         genre  year
# 0    flamenco  2000
# 1    flamenco  2000
# ...

# %%
df_fuente_json=pd.DataFrame(fuente_json)

# %%
print (df_fuente_json.head())
# Out:
#                        id     artist_name                  track_name  \
# 0  7AlYBA5M9FVXDqN31cbExE  Remedios Amaya                 El zarandeo
# 1  4uqcES2h19TKAXQlciycrO   Nobuo Uematsu          Vamo'alla flamenco
# 2  0z6xGK2u3nSsbk9XeKYwZQ   Maurice Ravel             Flamenco Bolero
# 3  6DjfWx0fXi0uQpedpvaCD9      Mark Towns              After the Rain
# 4  1t91qQaPbOoo4pumaLih4W  Franz Schubert  Tango Serenata (Ständchen)
#
#       genre  year
# 0  flamenco  2000
# 1  flamenco  2000
# 2  flamenco  2000
# 3  flamenco  2000
# 4  flamenco  2000

# %%
pd.read_json
pd.json_normalize(fuente_json)
# Out:
#                            id        artist_name                  track_name  \
# 0      7AlYBA5M9FVXDqN31cbExE     Remedios Amaya                 El zarandeo
# 1      4uqcES2h19TKAXQlciycrO      Nobuo Uematsu          Vamo'alla flamenco
# 2      0z6xGK2u3nSsbk9XeKYwZQ      Maurice Ravel             Flamenco Bolero
# 3      6DjfWx0fXi0uQpedpvaCD9         Mark Towns              After the Rain
# 4      1t91qQaPbOoo4pumaLih4W     Franz Schubert  Tango Serenata (Ständchen)
# ...                       ...                ...                         ...
# 61612  6Lv0uLFhPt6e4qcmoeltAq        Jade Macrae           Ain’t Nobody Home
# 61613  6Lv0uLFhPt6e4qcmoeltAq        Robben Ford           Ain’t Nobody Home
# 61614  4PtUbfBR2U2BC0uUrT9hnM    No Te Va Gustar                    Todo Mal
# 61615  4PtUbfBR2U2BC0uUrT9hnM  Ciro y los Persas                    Todo Mal
# 61616  762E489aCXNDuRg1sZaWmC            Artemas              time alone w u
#
#           genre  year
# ...

# %%
# sacar de fuente.json todos los archivos que lleva 'pop'
archivos_rap= [] # en esta variable introduzco todos los archivos que son de genre=pop

for elemento in fuente_json:
    
    if 'rap' in elemento['genre'].lower():
        archivos_rap.append(elemento)

print(archivos_rap)
# Out:
# [{'id': '4FXSEdmbbeGmPIQltH27C8', 'artist_name': 'La Oreja de Van Gogh', 'track_name': 'Pop', 'genre': 'rap', 'year': 2000}, {'id': '0plPN6zr3r0vW4VA0cTlmO', 'artist_name': 'Dany Bpm', 'track_name': 'I Want to Know what Love Is', 'genre': 'rap', 'year': 2000}, {'id': '4ZFvUk3xhvofhh3rCaQbq0', 'artist_name': 'D-4-MA', 'track_name': 'The Promise', 'genre': 'rap', 'year': 2000}, {'id': '3JISoccsWqVz9KGZUK6pPX', 'artist_name': 'Enigmatik', 'track_name': 'Apache', 'genre': 'rap', 'year': 2000}, {'id': '1Hb0K8CGqKNaj2sBvvSkT7', 'artist_name': 'Nina Gordon', 'track_name': '2003', 'genre': 'rap', 'year': 2000}, {'id': '5N0cZG9UCMBMeetIPGW8G5', 'artist_name': 'Nostalgi-K', 'track_name': 'The Spirit - 2001 Remix', 'genre': 'rap', 'year': 2001}, {'id': '3Z7mrMsAdiAVtmhQXkWHQV', 'artist_name': 'Chenoa', 'track_name': 'Lady Marmalade', 'genre': 'rap', 'year': 2001}, {'id': '3Z7mrMsAdiAVtmhQXkWHQV', 'artist_name': 'Gisela', 'track_name': 'Lady Marmalade', 'genre': 'rap', 'year': 2001}, {'id': '3Z7
# ...

# %%
archivos_rap
# Out:
# [{'id': '4FXSEdmbbeGmPIQltH27C8',
#   'artist_name': 'La Oreja de Van Gogh',
#   'track_name': 'Pop',
#   'genre': 'rap',
#   'year': 2000},
#  {'id': '0plPN6zr3r0vW4VA0cTlmO',
#   'artist_name': 'Dany Bpm',
#   'track_name': 'I Want to Know what Love Is',
#   'genre': 'rap',
#   'year': 2000},
#  {'id': '4ZFvUk3xhvofhh3rCaQbq0',
#   'artist_name': 'D-4-MA',
#   'track_name': 'The Promise',
#   'genre': 'rap',
#   'year': 2000},
#  {'id': '3JISoccsWqVz9KGZUK6pPX',
#   'artist_name': 'Enigmatik',
#   'track_name': 'Apache',
#   'genre': 'rap',
#   'year': 2000},
#  {'id': '1Hb0K8CGqKNaj2sBvvSkT7',
#   'artist_name': 'Nina Gordon',
#   'track_name': '2003',
#   'genre': 'rap',
#   'year': 2000},
#  {'id': '5N0cZG9UCMBMeetIPGW8G5',
#   'artist_name': 'Nostalgi-K',
#   'track_name': 'The Spirit - 2001 Remix',
#   'genre': 'rap',
#   'year': 2001},
#  {'id': '3Z7mrMsAdiAVtmhQXkWHQV',
#   'artist_name': 'Chenoa',
#   'track_name': 'Lady Marmalade',
#   'genre': 'rap',
#   'year': 2001},
# ...

# %%
#creo variables para pasar cada archivo por años
rap_2018=[]
rap_2019=[]
rap_2020=[]
rap_2021=[]
rap_2022=[]

# lo meto por un bucle for para iterar por el 

for archivo in archivos_rap:

    año_del_archivo = archivo['year']

    if año_del_archivo == 2018:
            rap_2018.append(archivo)

    elif año_del_archivo == 2019:
            rap_2019.append(archivo)

    elif año_del_archivo == 2020:
            rap_2020.append(archivo)

    elif año_del_archivo == 2021:
            rap_2021.append(archivo)

    elif año_del_archivo == 2022:
            rap_2022.append(archivo)

# Ahora puedes ver cuántos hay en cada una

print(f"En 2018 hay {len(rap_2018)} archivos rap.")
 
print(f"En 2019 hay {len(rap_2019)} archivos rap.")
print(f"En 2020 hay {len(rap_2020)} archivos rap.")
print(f"En 2021 hay {len(rap_2021)} archivos rap.")
print(f"En 2022 hay {len(rap_2022)} archivos rap.")
# Out:
# En 2018 hay 402 archivos rap.
# En 2019 hay 369 archivos rap.
# En 2020 hay 497 archivos rap.
# En 2021 hay 384 archivos rap.
# En 2022 hay 319 archivos rap.

# %%
##una vez tengo esto si quiero guardar este json.poop??

# %%
with open("Files/definitivo.json") as archivo_json:
    fuente_json = json.load(archivo_json)

# %%
artistas_unicos = sorted({ #Creamos un set (colección de elementos únicos, sin duplicados) y le ponemos un sorted porque los sets no tienen orden.
    elemento["artist_name"]
    for elemento in fuente_json #Recorre cada elemento de nuestro JSON (cada canción).
    if 2018 <= elemento["year"] <= 2022 and elemento["genre"].lower() == "rap" # Filtra solo las canciones cuyo año esté entre 2018 y 2022.Nos aseguramos de que asegura que solo se consideren elementos(canciones) de pop, sin importar mayúsculas/minúsculas
})

print("Artistas únicos de rap entre 2018 y 2022:")
for artista in artistas_unicos:
    print(artista)
# Out:
# Artistas únicos de rap entre 2018 y 2022:
# #HESHTEG#
# $TOKA
# $crappy G
# 0324 Crew
# 10 район
# 100kay
# 16FLIP
# 1nonly
# 1of1
# 21 Savage
# 2E
# 31 FAM
# 31st Youngin'
# 3OH!3
# 3fargo
# 3ohBlack
# 3t Brax
# 411
# 6Flame
# 6ix9ine
# 6osy
# 7.0.4
# 805 Clicka
# 9ockin
# A$AP Rocky
# AANG
# ANDRO
# ARVEIN RAJA
# ASID
# Ab-Rule
# Abiichiidii D
# Ace Dream
# Acts
# Adam Levine
# Adonis DaHottest
# Afrodite
# Afroman
# Agust D
# Akill Miami
# Alex Goot
# Alfonsina
# Alkogol Posle Sporta
# Alta Gracia
# Amatowsky
# Amenazzy
# Anane
# Ander Berg
# Angel Brown
# Ania Dudek
# Anis Don Demina
# Anne-Marie
# Anthony Hayes
# Anthony Stephens Jr.
# Arizona Zervas
# Arthrn
# Asidity7
# Atomic Otro Way
# Audrey Lopes
# Ava Max
# Awkward African
# Ayax y Prok
# Ayjay
# B.P.
# BBY KODIE
# BIA
# BKO
# BLOCK CREW
# BLOKE
# BUPPON
# Baby Keem
# Baby Ray
# Bad Gyal
# Bam
# Banda Cambaia
# Bandingo YGNE
# Bankroll Freddie
# Bardo José
# Bassirou Koureissi
# Baya Baye MGT Los Sosis
# Becky G
# Bekar
# ...

# %%
# Guardar en un archivo JSON - #Guardamos minijson_rap


with open("artistas_rap_2018_2022.json", "w", encoding="utf-8") as minijson_rap_artistas_unicos: #utf-8 asegura que los caracteres especiales (como acentos) se guarden correctamente
    json.dump(artistas_unicos, minijson_rap_artistas_unicos, ensure_ascii=False, indent=4) #ensure_ascii=False permite que el JSON guarde los caracteres especiales correctamente en su forma natural(tildes,ñ etc)indent :Cada elemento está en su propia línea y sangrado con 4 espacios

# %% [markdown]
# Tenemos un minijson del Json definitivo_spoty que tiene una lista con los artistas unicos durante los años 18-22
