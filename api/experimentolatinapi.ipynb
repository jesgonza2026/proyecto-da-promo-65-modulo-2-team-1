# %%
import mysql.connector
from mysql.connector import errorcode
import pandas as pd
import requests
import json

# %%
api_key_last_fm = "37c58183529191eefb53d80df3c328ec"  #esta puesta mi apiKey

url2 = "http://ws.audioscrobbler.com/2.0/"

# %%
url = "http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=Slipknot&api_key=37c58183529191eefb53d80df3c328ec&format=json"

# %%
 #Hacemos la petición a un API de ejemplo.
response = requests.get(url) # Esta dirección es el famoso "endpoint".

# Mostramos la respuesta que nos devuelve el API.

# %%
response.status_code
# Out:
# 200

# %%
datos_artista = response.json()

# %%
datos_artista #hemos hecho contacto y llegado al dato del artista
# Out:
# {'artist': {'name': 'Slipknot',
#   'mbid': 'a466c2a2-6517-42fb-a160-1087c3bafd9f',
#   'url': 'https://www.last.fm/music/Slipknot',
#   'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'small'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'medium'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'large'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'extralarge'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': 'mega'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#     'size': ''}],
#   'streamable': '0',
#   'ontour': '0',
#   'stats': {'listeners': '4168449', 'playcount': '356582811'},
# ...

# %%
type(datos_artista)
# Out:
# dict

# %%
datos_artista.keys()
# Out:
# dict_keys(['artist'])

# %%
datos_artista['artist']
# Out:
# {'name': 'Slipknot',
#  'mbid': 'a466c2a2-6517-42fb-a160-1087c3bafd9f',
#  'url': 'https://www.last.fm/music/Slipknot',
#  'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#    'size': 'small'},
#   {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#    'size': 'medium'},
#   {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#    'size': 'large'},
#   {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#    'size': 'extralarge'},
#   {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#    'size': 'mega'},
#   {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#    'size': ''}],
#  'streamable': '0',
#  'ontour': '0',
#  'stats': {'listeners': '4168449', 'playcount': '356582811'},
# ...

# %%
type(datos_artista['artist'])
# Out:
# dict

# %%
datos_artista['artist'].keys()
# Out:
# dict_keys(['name', 'mbid', 'url', 'image', 'streamable', 'ontour', 'stats', 'similar', 'tags', 'bio'])

# %%
datos_artista['artist']['name']
# Out:
# 'Slipknot'

# %%
datos_artista['artist']['stats'].keys()
# Out:
# dict_keys(['listeners', 'playcount'])

# %%
datos_artista['artist']['stats']['listeners']
# Out:
# '4168449'

# %%
datos_artista['artist']['similar'].keys()
#exploramos como acceder al diccionario de artistas similares
# Out:
# dict_keys(['artist'])

# %%
datos_artista['artist']['similar']['artist'][0].keys()
# Out:
# dict_keys(['name', 'url', 'image'])

# %%
datos_artista['artist']['similar']['artist'][0]['name']
# Out:
# 'Korn'

# %% [markdown]
# Hacemos las variables de las llamadas

# %%
nombre = datos_artista['artist']['name']
audiencia = datos_artista['artist']['stats']['listeners']
reproducciones = datos_artista['artist']['stats']['playcount']
artistas_similares = datos_artista['artist']['similar']['artist'][0]['name'] #aca he puesto solo la primera ocurrencia
nombres_similares = [s['name'] for s in datos_artista['artist']['similar']['artist']] #list comprehension
biografia = datos_artista['artist']['bio']['content']

# %%
# Esto crea una lista de strings: ['Megadeth', 'Slayer', 'Pantera'...]
nombres_similares = [s['name'] for s in datos_artista['artist']['similar']['artist']]

print(nombres_similares)
# Out:
# ['Korn', 'Stone Sour', 'System of a Down', 'Mudvayne', 'Vended']

# %%
datos_artista['artist']['bio']
# Out:
# {'links': {'link': {'#text': '',
#    'rel': 'original',
#    'href': 'https://last.fm/music/Slipknot/+wiki'}},
#  'published': '10 Feb 2006, 21:16',
#  'summary': 'Slipknot is an American heavy metal band formed in Des Moines, Iowa, in 1995 by percussionist Shawn " Clown" Crahan, vocalist/percussionist Anders Colsefni, and bassist Paul Gray. After several lineup changes in its early years, the band settled on a nine-member lineup for more than a decade, consisting of  Crahan, Gray, Joey Jordison, Craig "133" Jones, Mick Thomson, Corey Taylor, Sid Wilson, Chris Fehn, and Jim Root. Slipknot is known for its distinctive visual presentation, aggressive musical style, and intense live performances. <a href="https://www.last.fm/music/Slipknot">Read more on Last.fm</a>',
# ...

# %%
datos_artista['artist']['bio'].keys()
# Out:
# dict_keys(['links', 'published', 'summary', 'content'])

# %%
datos_artista['artist']['bio']['content']
# Out:
# 'Slipknot is an American heavy metal band formed in Des Moines, Iowa, in 1995 by percussionist Shawn " Clown" Crahan, vocalist/percussionist Anders Colsefni, and bassist Paul Gray. After several lineup changes in its early years, the band settled on a nine-member lineup for more than a decade, consisting of  Crahan, Gray, Joey Jordison, Craig "133" Jones, Mick Thomson, Corey Taylor, Sid Wilson, Chris Fehn, and Jim Root. Slipknot is known for its distinctive visual presentation, aggressive musical style, and intense live performances.\n\nThe band’s debut demo album, "Mate. Feed. Kill. Repeat." (1996), received limited attention, but Slipknot gained widespread recognition following the release of its self-titled debut studio album, "Slipknot", in 1999. Its second studio album, "Iowa" (2001), further increased the band’s popularity. After a brief hiatus, Slipknot returned in 2004 with "Vol. 3: (The Subliminal Verses)". The band later released "All Hope Is Gone" in 2008, which debuted at
# ...

# %%
#aca es que se escoje el json por genero
with open('Files/artistas_latin_2018_2022.json', 'r', encoding='utf-8') as f:
    lista_artistas_latin = json.load(f)

# %%
lista_artistas_latin
# Out:
# ['$kyhook',
#  '3AM',
#  '6ix9ine',
#  'ABHIR',
#  'ABRA',
#  'Abraham Mateo',
#  'Aitana',
#  'Alberdi',
#  'Alejo',
#  'Alex Gargolas',
#  'Alex Goot',
#  'Alex Rose',
#  'Almighty',
#  'Alvaro Diaz',
#  'Alvaro Soler',
#  'Alzate',
#  'Amenazzy',
#  'Ana Mena',
#  'Andy Rivera',
#  'Anne-Marie',
#  'Antonio Banderas',
#  'Antonio José',
#  'Anuel',
#  'Anuel AA',
#  'Arcángel',
#  'Asan',
#  'Atomic Otro Way',
#  'Aventura',
#  'B-Case',
#  'BEJO',
#  'BM',
#  'Baby Rasta',
#  'Bad Bunny',
#  'Bad Gyal',
#  'Bad Milk',
#  'Bandaga',
#  'Bardero$',
#  'Bassy',
#  'Beatriz Luengo',
#  'Bebe',
#  'Becky G',
#  'Belinda',
#  'Beny Jr',
#  'Beret',
#  'Beéle',
#  'Big Soto',
#  'Billie Eilish',
#  'Billy Chester',
#  'Biwan La Pauta',
#  'Bizarrap',
#  'Blessd',
#  'BlueFire',
#  'Bomba Estéreo',
#  'Boricua Boys',
#  'Boy Wonder CF',
#  'Boza',
#  'Brray',
#  'Bruno Romano',
#  'Bryant Myers',
#  'Brytiago',
#  'Bujan',
#  'Buscabulla',
#  'Busy Signal',
#  'C de Cama',
# ...

# %%
pd.DataFrame(lista_artistas_latin)
# Out:
#                   0
# 0           $kyhook
# 1               3AM
# 2           6ix9ine
# 3             ABHIR
# 4              ABRA
# ..              ...
# 547          tatool
# 548      Çantamarta
# 549  Íñigo Quintero
# 550            Ñejo
# 551      Ñengo Flow
#
# [552 rows x 1 columns]

# %% [markdown]
# hubo que agregar 3 cosas:
# headers = {'User-Agent': 'MiBootcampApp/1.0'} # <--- Esto es vital para evitar el 403
#
#  print(f"❌ Error 403 en {artista}: Revisa tu API Key o el User-Agent.")
#             break # Si es 403, mejor paramos para investigar
#
#         # Un pequeño respiro para no saturar la API
#         time.sleep(0.1)

# %%
import requests
import time

# 1. Tu configuración (Revisa bien tu API Key)
api_key_last_fm = "dffc96fb5e37b49d6382379a54a66094"
headers = {'User-Agent': 'MiBootcampApp/1.0'} # <--- Esto es vital para evitar el 403
url = "http://ws.audioscrobbler.com/2.0/"

diccionario_latin = {"artista" : [], "audiencia" : [], "reproducciones" : [], "similares" : [], "biografia": []}

for artista in lista_artistas_latin:
    # 2. NO pongas los datos en la URL manualmente. 
    # Deja que 'requests' se encargue de limpiar los espacios y tildes.
    parametros = {
        "method": "artist.getinfo",
        "artist": artista,
        "api_key": api_key_last_fm,
        "format": "json"
    }

    try:
        # Pasamos los parámetros por separado
        response = requests.get(url, params=parametros, headers=headers)
        
        if response.status_code == 200:
            datos_api = response.json()
            
            if 'artist' in datos_api:
                info = datos_api['artist']
                
                diccionario_latin["artista"].append(info.get('name', artista))
                diccionario_latin["audiencia"].append(info['stats'].get('listeners', 0))
                diccionario_latin["reproducciones"].append(info['stats'].get('playcount', 0))
                
                # Extraemos similares (si existen)
                similares = [s['name'] for s in info.get('similar', {}).get('artist', [])]
                diccionario_latin["similares"].append(similares)
                
                # Biografía
                bio = info.get('bio', {}).get('content', 'Sin biografía')
                diccionario_latin["biografia"].append(bio)
                
                print(f"✅ {artista} recuperado correctamente.")
            else:
                print(f"⚠️ {artista} no existe en Last.fm.")
        
        elif response.status_code == 403:
            print(f"❌ Error 403 en {artista}: Revisa tu API Key o el User-Agent.")
            break # Si es 403, mejor paramos para investigar
            
        # Un pequeño respiro para no saturar la API
        time.sleep(0.1)

    except Exception as e:
        print(f"💥 Error inesperado con {artista}: {e}")

print("Proceso terminado.")
# Out:
# ✅ $kyhook recuperado correctamente.
# ✅ 3AM recuperado correctamente.
# ✅ 6ix9ine recuperado correctamente.
# ✅ ABHIR recuperado correctamente.
# ✅ ABRA recuperado correctamente.
# ✅ Abraham Mateo recuperado correctamente.
# ✅ Aitana recuperado correctamente.
# ✅ Alberdi recuperado correctamente.
# ✅ Alejo recuperado correctamente.
# ✅ Alex Gargolas recuperado correctamente.
# ✅ Alex Goot recuperado correctamente.
# ✅ Alex Rose recuperado correctamente.
# ✅ Almighty recuperado correctamente.
# ✅ Alvaro Diaz recuperado correctamente.
# ✅ Alvaro Soler recuperado correctamente.
# ✅ Alzate recuperado correctamente.
# ✅ Amenazzy recuperado correctamente.
# ✅ Ana Mena recuperado correctamente.
# ✅ Andy Rivera recuperado correctamente.
# ✅ Anne-Marie recuperado correctamente.
# ✅ Antonio Banderas recuperado correctamente.
# ✅ Antonio José recuperado correctamente.
# ✅ Anuel recuperado correctamente.
# ✅ Anuel AA recuperado correctamente.
# ✅ Arcángel recuperado correctamente.
# ...

# %%
diccionario_latin
# Out:
# {'artista': ['$kyhook',
#   '3am',
#   '6ix9ine',
#   'Abhir',
#   'Abra',
#   'Abraham Mateo',
#   'Aitana',
#   'Alberdi',
#   'Alejo',
#   'Alex Gargolas',
#   'Alex Goot',
#   'Alex Rose',
#   'Almighty',
#   'Alvaro Diaz',
#   'Alvaro Soler',
#   'Alzate',
#   'Amenazzy',
#   'Ana Mena',
#   'Andy Rivera',
#   'Anne-Marie',
#   'Antonio Banderas',
#   'Antonio José',
#   'Anuel',
#   'Anuel AA',
#   'Arcángel',
#   'Asan',
#   'Atomic Otro Way',
#   'Aventura',
#   'B-Case',
#   'Bejo',
#   'BM',
#   'Baby Rasta',
#   'Bad Bunny',
#   'Bad Gyal',
#   'Bad Milk',
#   'bandaga',
#   'Bardero$',
#   'bassy',
#   'Beatriz Luengo',
#   'Bebe',
#   'Becky G',
#   'Belinda',
#   'Beny Jr',
#   'beret',
#   'Beéle',
#   'Big Soto',
#   'Billie Eilish',
#   'Billy Chester',
#   'Biwan La Pauta',
#   'Bizarrap',
#   'Blessd',
#   'Bluefire',
#   'Bomba Estéreo',
#   'Boricua Boys',
#   'Boy Wonder Cf',
#   'Boza',
#   'Brray',
#   'Bruno Romano',
#   'Bryant Myers',
#   'Brytiago',
# ...

# %%
#guardamos el dataframe
df_latin_lastfm = pd.DataFrame(diccionario_latin)

# %%
df_latin_lastfm.to_json('files/datos_latin_apilastfm.json', orient='records', indent=4, force_ascii=False)

print("¡Archivo JSON guardado con éxito!")
# Out:
# ¡Archivo JSON guardado con éxito!
